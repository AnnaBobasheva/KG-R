# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaBobasheva/KG-R/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("reticulate")
library(reticulate)
os <- import("os")
os$listdir(".")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘RcppTOML’, ‘here’, ‘png’
# [1] ".config"     "sample_data"

# %%
pip <- import("pip")
pip$"__version__"
# Out:
# [1] "22.0.4"

# %%
library(reticulate)
py_install("ipyleaflet")
leaflet <- import(ipyleaflet)
# Out:
# Using virtual environment '~/.virtualenvs/r-reticulate' ...
# Warning message in system2(python, c("-c", shQuote(command)), stdout = TRUE, stderr = TRUE):
# “running command ''/root/.virtualenvs/r-reticulate/bin/python' -c 'import sys; import pip; sys.stdout.write(pip.__version__)' 2>&1' had status 1”
# Error in if (idx != -1) version <- substring(version, 1, idx - 1): the condition has length > 1
# Traceback:
#
# 1. py_install("ipyleaflet")
# 2. virtualenv_install(envname = envname, packages = packages, ignore_installed = pip_ignore_installed,
#  .     ...)
# 3. pip_version(python)

# %%
!ls
# Out:
# Error in !ls: invalid argument type
# Traceback:

# %%
install.packages("ggmap")
library("ggmap")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sp’, ‘RgoogleMaps’, ‘plyr’, ‘jpeg’, ‘bitops’
#
#
# Loading required package: ggplot2
#
# ℹ Google's Terms of Service: <https://mapsplatform.google.com>
#
# ℹ Please cite ggmap if you use it! Use `citation("ggmap")` for details.

# %%
us <- c(left = -125, bottom = 25.75, right = -67, top = 49)
get_stamenmap(us, zoom = 5, maptype = "toner-lite") %>% ggmap()
# Out:
# ℹ Map tiles by Stamen Design, under CC BY 3.0. Data by OpenStreetMap, under ODbL.
# plot without title
